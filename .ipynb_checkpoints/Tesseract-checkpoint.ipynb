# %%
import tesserocr # Para hacer OCR
#pip install tesserocr
import numpy as np # Para hacer manipulación básica de imágenes
import matplotlib.pyplot as plt # Para visualizar imágenes
from PIL import Image # Para cambiar el formato de archivos
# %matplotlib inline

# %%
texto_largo = plt.imread('texto-img.png')
plt.figure(figsize=(15,5))
plt.imshow(texto_largo)
plt.axis(False);

# %%
texto_ocr = tesserocr.file_to_text('texto-img.png', lang='spa')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-83c0d7eac9a4> in <module>
# ----> 1 texto_ocr = tesserocr.file_to_text('texto-img.png', lang='spa')
#
# tesserocr.pyx in tesserocr._tesserocr.file_to_text()
#
# RuntimeError: Failed to init API, possibly an invalid tessdata path: C:\Users\Angelica\anaconda3\/tessdata/

# %%
path = 'C:\\Users\\Angelica\\Desktop\\CoWie - USCO\\texto-img.png'
image = Image.open(path)
print(tesserocr.image_to_text(image))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-a54b99237311> in <module>
#       1 path = 'C:\\Users\\Angelica\\Desktop\\CoWie - USCO\\texto-img.png'
#       2 image = Image.open(path)
# ----> 3 print(tesserocr.image_to_text(image))
#
# tesserocr.pyx in tesserocr._tesserocr.image_to_text()
#
# RuntimeError: Failed to init API, possibly an invalid tessdata path: C:\Users\Angelica\anaconda3\/tessdata/

# %%
print(tesserocr.tesseract_version())
print(tesserocr.get_languages())
# Out:
# tesseract 4.0.0
#  leptonica-1.76.0 (Jan  8 2019, 13:34:23) [MSC v.1900 LIB Release x64]
#   libgif 5.1.4 : libjpeg 9b : libpng 1.6.35 : libtiff 4.0.9 : zlib 1.2.11 : libwebp 0.6.1 : libopenjp2 2.3.0
# ('C:\\Users\\Angelica\\anaconda3\\/tessdata/', [])

# %%
image = Image.open('texto-img.png')

# %%
print(tesserocr.file_to_text(image, lang='kor'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-400c07723350> in <module>
# ----> 1 print(tesserocr.file_to_text(image, lang='kor'))
#
# tesserocr.pyx in tesserocr._tesserocr.file_to_text()
#
# tesserocr.pyx in tesserocr._tesserocr._b()
#
# TypeError: Expected bytes, got PngImageFile

# %%
import tesserocr
import os
from PIL import Image

os.chdir(r"C:\Users\Angelica\anaconda3\Lib\site-packages\tesserocr")
image = Image.open('texto-img.png')
print(tesserocr.image_to_text(image))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-16e200f323fa> in <module>
#       5 os.chdir(r"C:\Users\Angelica\anaconda3\Lib\site-packages\tesserocr")
#       6 image = Image.open('texto-img.png')
# ----> 7 print(tesserocr.image_to_text(image))
#
# tesserocr.pyx in tesserocr._tesserocr.image_to_text()
#
# RuntimeError: Failed to init API, possibly an invalid tessdata path: C:\Users\Angelica\anaconda3\/tessdata/

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

text = pytesseract.image_to_string(image)
print('Texto: ', text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     237     try:
# --> 238         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     239     except OSError as e:
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...
